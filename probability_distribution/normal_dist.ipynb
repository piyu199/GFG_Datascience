# %%
from scipy import stats
import numpy as np
from matplotlib import pyplot as plt

# %%
x_data = np.linspace(-5,5,10000)
x_data
# Out:
# array([-5.       , -4.9989999, -4.9979998, ...,  4.9979998,  4.9989999,
#         5.       ])

# %%
y_data = stats.norm.pdf(x_data,0,1)
y_data
# Out:
# array([1.48671951e-06, 1.49417173e-06, 1.50165979e-06, ...,
#        1.50165979e-06, 1.49417173e-06, 1.48671951e-06])

# %%
plt.plot(x_data,y_data)

# %%
y_data2 = stats.norm.pdf(x_data,0,10)
plt.plot(x_data,y_data2)

# %%
z_data = stats.norm.pdf(x_data,3,1)
plt.plot(x_data,z_data)
